# %% [markdown]
# # Restaurant Tips Data Analysis
#  Author: Harry Bien-Aime
#
# ## Objective
# The objective of this project is to explore the relationship between restaurant bills and tipping behavior using a real dataset.
#
#  Tools Used
# - Python
# - Pandas
# - Seaborn
# - Matplotlib
# - Jupyter Notebook

# %% [markdown]
# ## Dataset Description
#
# This dataset contains information about restaurant bills and tips.
#
# Variables include:
#
# - total_bill: total amount of the bill
# - tip: tip amount given
# - sex: gender of the customer
# - smoker: whether the customer is a smoker
# - day: day of the week
# - time: lunch or dinner
# - size: number of people at the table

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset("tips")

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Exploratory Data Analysis
#
# In this section we explore patterns in tipping behavior using data visualizations.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data=df, x="total_bill", y="tip")

plt.title("Relationship Between Total Bill and Tip")

plt.show()

# %% [markdown]
# ### Insight
#
# The scatter plot shows that tips generally increase as the total bill increases.
# Customers who spend more tend to leave larger tips.

# %%
sns.histplot(df["tip"], bins=20)

plt.title("Distribution of Tips")

plt.show()

# %% [markdown]
# ### Insight
#
# Most tips fall between $2 and $4, indicating a common tipping range.

# %%
sns.boxplot(data=df, x="day", y="tip")

plt.title("Tips by Day of the Week")

plt.show()

# %% [markdown]
# ### Insight
#
# The boxplot suggests that tips may be slightly higher on weekends, particularly Saturday and Sunday.

# %% [markdown]
# ## Conclusion
#
# This analysis explored tipping behavior in restaurants.
#
# Key findings:
#
# - Tips generally increase as the total bill increases.
# - Most tips fall between $2 and $4.
# - Weekend days tend to show slightly higher tipping patterns.
#
# These insights demonstrate how simple exploratory data analysis can reveal patterns in customer behavior.
